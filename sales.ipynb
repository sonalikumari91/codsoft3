# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from  sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv(r"C:\Users\Gaurav\OneDrive\Desktop\codsoft project3\codsoft 3 sales production\advertising (1).csv")

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
df.size
# Out:
# 800

# %%
df.shape
# Out:
# (200, 4)

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
df.hist(bins=50)
plt.show()

# %%
plt.subplot(1, 3, 1)
sns.histplot(df['TV'], kde=True, color='blue', bins=20)
plt.title('TV Advertisement')
# Out:
# Text(0.5, 1.0, 'TV Advertisement')

# %%
plt.subplot(1, 3, 3)
sns.histplot(df['Newspaper'], kde=True, color='red', bins=20)
plt.title('Newspaper Advertisement')
# Out:
# Text(0.5, 1.0, 'Newspaper Advertisement')

# %%
sns.boxplot(data=df)
plt.title('Sales Advertisement')
# Out:
# Text(0.5, 1.0, 'Sales Advertisement')

# %%
plt.style.use('dark_background')
sns.scatterplot(x='TV', y='Sales', data=df, color='blue')
plt.title('TV Advertisement vs Sales')
# Out:
# Text(0.5, 1.0, 'TV Advertisement vs Sales')

# %%
sns.scatterplot(x='Radio', y='Newspaper', data=df,hue="Sales", color='green')
plt.title('Radio Advertisement vs Sales')
# Out:
# Text(0.5, 1.0, 'Radio Advertisement vs Sales')

# %%
sns.scatterplot(x='Newspaper', y='Sales', data=df, color='red')
plt.title('Newspaper Advertisement vs Sales')
# Out:
# Text(0.5, 1.0, 'Newspaper Advertisement vs Sales')

# %%
sns.scatterplot(x='Radio', y='Sales',data=df)
plt.title("Radio vs Sales")
# Out:
# Text(0.5, 1.0, 'Radio vs Sales')

# %%
correlation = df[['TV', 'Radio', 'Newspaper', 'Sales']].corr()
print(correlation)
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.901208
# Radio      0.054809  1.000000   0.354104  0.349631
# Newspaper  0.056648  0.354104   1.000000  0.157960
# Sales      0.901208  0.349631   0.157960  1.000000

# %%
sns.heatmap(correlation, annot=True, linewidths=0.5)
# Out:
# <Axes: >

# %%
statistics= df[['TV','Radio','Newspaper']].describe()
print(statistics)
# Out:
#                TV       Radio   Newspaper
# count  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000
# std     85.854236   14.846809   21.778621
# min      0.700000    0.000000    0.300000
# 25%     74.375000    9.975000   12.750000
# 50%    149.750000   22.900000   25.750000
# 75%    218.825000   36.525000   45.100000
# max    296.400000   49.600000  114.000000

# %%
max_values = statistics.loc['max']
print("\nMaximum values:")
print(max_values)
# Out:
# Maximum values:
# TV           296.4
# Radio         49.6
# Newspaper    114.0
# Name: max, dtype: float64

# %%
min_values = statistics.loc['min']
print("\n minimum values:")
print(min_values)
# Out:
#  minimum values:
# TV           0.7
# Radio        0.0
# Newspaper    0.3
# Name: min, dtype: float64

# %%
sns.set_style('white')
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='TV', hue='Sales', bins=20, kde=True, alpha=0.7)
sns.histplot(data=df, x='Newspaper', hue='Sales', bins=20, kde=True, alpha=0.7)
sns.histplot(data=df, x='Radio', hue='Sales', bins=20, kde=True, alpha=0.7)

plt.xlabel('Advertising ')
plt.ylabel('Frequency')
plt.title('Histogram of Advertising with Sales Hue')
plt.legend(title='Sales')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
median_values = statistics.loc['50%'] 
print("\nMedian values:")
print(median_values)
# Out:
# Median values:
# TV           149.75
# Radio         22.90
# Newspaper     25.75
# Name: 50%, dtype: float64

# %%
sns.histplot(df['Sales'],kde=True)
# Out:
# <Axes: xlabel='Sales', ylabel='Count'>

# %%
x=df.drop('Sales',axis=1)
y=df['Sales']

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.head()
# Out:
#         TV  Radio  Newspaper
# 79   116.0    7.7       23.1
# 197  177.0    9.3        6.4
# 38    43.1   26.7       35.1
# 24    62.3   12.6       18.3
# 122  224.0    2.4       15.6

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((160, 3), (40, 3), (160,), (40,))

# %%
scaler=StandardScaler()
x_train_scaled=scaler.fit_transform(x_train)
x_test_scaled=scaler.fit_transform(x_test)

# %%
plt.subplots(figsize=(15,5))
plt.subplot(1,2,1)
sns.boxplot(data=x_train)
plt.title('x_train before scaling')
plt.subplot(1,2,2)
sns.boxplot(data=x_train_scaled)
plt.title('x_train after scaling')
# Out:
# Text(0.5, 1.0, 'x_train after scaling')

# %%
linear_reg = LinearRegression()
linear_reg.fit(x_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error

# %%
y_pred = linear_reg.predict(x_test_scaled)
mse = mean_squared_error(y_test, y_pred)
print("Linear Regression Mean Squared Error:", mse)
# Out:
# Linear Regression Mean Squared Error: 3.816735456943519

# %%
import pickle
pickle.dump(scaler,open('scaler.pkl','wb'))
pickle.dump(linear_reg,open('linear.pkl','wb'))
